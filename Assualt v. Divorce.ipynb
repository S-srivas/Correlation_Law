# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import matplotlib.pyplot as plt
from pylab import bar, show, plot

# %%
df=pd.read_csv('A Assaults.csv', parse_dates=['Year'], index_col='Year')

def plot_plots(df, x, y, title="", xlabel='Year', ylabel='Amount', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='green', label='Aggravated Assualt')
    #plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    #plt.plot(x, z, color='red', label='Divorce')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    #plt.xticks(rotation=90)
    
    #plt.show()
# Here, the two datdaframes are combined
#df_two = pd.concat([df, df_smallcols])
plot_plots(df, x=df.index, y=df.Number, title='Aggravated Assualts')

# %%
df1 = pd.read_csv('Divorce.csv')
def plot_plots(df1, x, y, title="", xlabel='Year', ylabel='Amount', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    #plt.plot(x, y, color='green', label='Aggravated Assualt')
    #plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.plot(x, y, color='red', label='Divorce')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    #plt.xticks(rotation=90)
    
    #plt.show()
# Here, the two datdaframes are combined
plot_plots(df1, x=df.index, y=df.Divorce, title='Aggravated Assualts v. Divorce')

# %%
# Finished: 9/21/19
# On this step, I'm importing the data
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt; plt.rcdefaults()
import matplotlib.pyplot as plt
from pylab import bar, show, plot

df=pd.read_csv('A Assaults.csv', parse_dates=['Year'], index_col='Year')
df_smallcols = pd.read_csv('Divorce.csv')

# %%
# Here, I'mm defining the funtion which does everything
def plot_plots(df, x, y, z, title="", xlabel='Year', ylabel='Amount', dpi=100):
    plt.figure(figsize=(16,5), dpi=dpi)
    plt.plot(x, y, color='green', label='Aggravated Assualt')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.plot(x, z, color='red', label='Divorce')
    plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    #plt.xticks(rotation=90)
    
    #plt.show()
# Here, the two datdaframes are combined
#df_two = pd.concat([df, df_smallcols])
plot_plots(df, x=df.index, y=df.Number, z=df_smallcols, title='Aggravated Assualts v. Divorce')

# %%
df.head()
# Out:
#             Number
# Year
# 2000-01-01  911706
# 2001-01-01  909023
# 2002-01-01  891407
# 2003-01-01  859030
# 2004-01-01  847381

# %%
df_smallcols.head()
# Out:
#    Year  Divorce
# 0  2000   944000
# 1  2001   940000
# 2  2002   955000
# 3  2003   927000
# 4  2004   879000

# %%
correlation_matrix = df_two.corr()

# %%
plt.imshow(correlation_matrix,cmap='hot',interpolation='nearest')
